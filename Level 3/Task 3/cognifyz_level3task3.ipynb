# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the Dataset

# %%
# Load the Dataset
df = pd.read_csv("Dataset .csv")

# %% [markdown]
# # Data Preprocessing

# %%
# Data Preprocessing
df = df[['Cuisines', 'Aggregate rating', 'Votes', 'City']]  # Selecting relevant columns
df.dropna(inplace=True)  # Dropping missing values

# %% [markdown]
# # Data Visulization

# %%
# 1. Distribution of Ratings - Histogram
plt.figure(figsize=(8, 5))
sns.histplot(df['Aggregate rating'], bins=20, kde=True, color='skyblue')
plt.title("Distribution of Restaurant Ratings")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %%
# 2. Average Rating of Different Cuisines - Bar Plot
cuisine_ratings = df.groupby('Cuisines')['Aggregate rating'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 5))
sns.barplot(x=cuisine_ratings.values, y=cuisine_ratings.index, palette='coolwarm')
plt.title("Top 10 Cuisines by Average Rating")
plt.xlabel("Average Rating")
plt.ylabel("Cuisine")
plt.show()

# %%
# 3. Average Rating by City - Bar Plot
city_ratings = df.groupby('City')['Aggregate rating'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 5))
sns.barplot(x=city_ratings.values, y=city_ratings.index, palette='viridis')
plt.title("Top 10 Cities by Average Restaurant Rating")
plt.xlabel("Average Rating")
plt.ylabel("City")
plt.show()

# %%
# 4. Relationship Between Votes and Ratings - Scatter Plot
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df['Votes'], y=df['Aggregate rating'], alpha=0.5, color='purple')
plt.title("Votes vs Rating")
plt.xlabel("Number of Votes")
plt.ylabel("Rating")
plt.show()

# %%
# 5. Boxplot of Ratings by Cuisine Type
top_cuisines = df['Cuisines'].value_counts().index[:10]  # Selecting top 10 cuisines
df_top = df[df['Cuisines'].isin(top_cuisines)]

plt.figure(figsize=(12, 6))
sns.boxplot(x="Cuisines", y="Aggregate rating", data=df_top, palette="coolwarm")
plt.xticks(rotation=45)
plt.title("Rating Distribution by Top 10 Cuisines")
plt.xlabel("Cuisine Type")
plt.ylabel("Rating")
plt.show()
